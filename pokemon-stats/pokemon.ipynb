# %% [markdown]
# # Pokemon Data Set
# This data set includes all pokemon currently in the game. It includes their name, types, combat stats, generation, and Legendary status.
# <br>
# This notebook will explore this data with graphs and draw conclusions based on findings.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
# Show the first 5 rows of the data set.
# Show the info of the data set.
df = pd.read_csv('./Pokemon.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
x = df['Attack'].values
y = df['Defense'].values

# %%
X = x.reshape(-1,1)
x_train, x_test, y_train, y_test = train_test_split(X,y,train_size=0.8, test_size=0.2, random_state=100)

# %%
# %matplotlib inline
plt.scatter(x_train, y_train, color='purple')
plt.xlabel('Attack Value')
plt.ylabel('Defense Value')
plt.title('Pokemon Power Level')
plt.show()

# %%
lm = LinearRegression()
lm.fit(x_train, y_train)
y_predict = lm.predict(x_test)
print(f"Train Accuracy {round(lm.score(x_train, y_train)*100,2)}%")
print(f"Test Accuracy {round(lm.score(x_test, y_test)*100,2)}%")
# Out:
# Train Accuracy 19.42%
# Test Accuracy 17.92%

# %%
plt.scatter(x_train, y_train, color = 'Purple')
plt.plot(x_test, y_predict)
plt.xlabel("Attack Value")
plt.ylabel("Defense Value")
plt.title('Pokemon Power Level')
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %% [markdown]
# # Conclusions
# ## The only clear conclusion is that pokemon above the blue line are solid, and the ones below are not worth your time. This also shows how unbalanced pokemon truly are, as there are clearly outliers for both defensive and offenseive power levels.
#
# #### A side note, this graph doesnt take in any other stats which would be ideal, but im not sure how to include those into my analysis yet. I would also love to be able to see the names of which pokemon are above the blue line, but I dont knokw how to do that yet either.
